# %%
### 1) PREP
######################################################################

# Load necessary packages

import pandas as pd
from openpyxl import load_workbook
import matplotlib.pyplot as plt
import os.path
import os
import numpy as np
from sklearn.linear_model import LinearRegression

# trying p-values
import statsmodels.api as sm
from scipy import stats
import math

# To print colored text
from termcolor import colored

# %%
# Set path

path = '/Users/sakshimohan/Dropbox (Personal)/District Allocation Formula/1. Final Documents/Data/input'
os.chdir(path)
#os.getcwd() # check path

# %%
# Load dataset

wb = load_workbook('RAF_Final Dataset_v3.xlsm', data_only=True)
sheet = wb['Data for Python']

# %%
### 2) DATAFRAME SET-UP
######################################################################

df = pd.DataFrame(sheet.values)
df = df.T # transpose
df.columns = df.iloc[0] # re-index
df = df.reindex(df.index.drop(0))

df = df.iloc[0:38,] # drop empty rows ## V2
df["District"] = df["Variable/District"]
df = df.set_index("Variable/District")

# Drop repeated data (i.e. disaggregated city and district data where the same local government controls the health budget)
df = df.drop("Mzimba", axis=0)
df = df.drop("Blantyre City", axis=0)
df = df.drop("Lilongwe City", axis=0)
df = df.drop("Mzuzu City", axis=0)
df = df.drop("Zomba City", axis=0)
df = df.drop("Blantyre", axis=0)
df = df.drop("Lilongwe", axis=0)
df = df.drop("Mzimba North", axis=0)
df = df.drop("Zomba", axis=0)

df
# Out:
# 0                       Females 15-49 Women age 15-49 currently pregnant (%)  \
# Variable/District
# Chitipa                         52347                                    7.6
# Karonga                         85155                                    8.7
# Nkhata Bay                      69166                                    8.2
# Rumphi                          52650                                    6.9
# Likoma                           2640                                    6.7
# Kasungu                        203948                                    6.8
# Nkhotakota                      93646                                    7.6
# Ntchisi                         67800                                    9.1
# Dowa                           194982                                    5.9
# Salima                         106220                                    9.3
# Mchinji                        142932                                    8.7
# Dedza                          181610                                    7.5
# Ntcheu                         138243                                    7.4
# Mangochi                       264886                                    9.8
# Machinga                       155149                                   10.1
# Chiradzulu                      79049                                    6.9
# Mwanza                        25439.5                                    5.6
# Thyolo                         161300                                    6.4
# Mulanje                        146000                                    6.2
# Phalombe                        95256                                    8.1
# Chikwawa                       132281                                    7.1
# Nsanje                          69196                                    8.4
# Balaka                         100168                                    8.9
# Neno                            43066                                    8.4
# Mzimba South                   114646                                    8.3
# Blantyre - combined            363754                                    4.4
# Zomba - combined               207124                                    7.8
# Lilongwe - combined            668437                                    8.3
# Mzimba North - combined        181918                                    8.3
#
# 0                       Lives births (amended) Population 15-49  \
# Variable/District
# Chitipa                                   6052            99209
# Karonga                                   8853           164234
# Nkhata Bay                                5466           136726
# Rumphi                                    4742           104209
# Likoma                                     446             5123
# Kasungu                                  19573           407137
# Nkhotakota                               11923           185306
# Ntchisi                                   7641           133293
# Dowa                                     17256           385446
# Salima                                   14753           198205
# Mchinji                                  17382           286040
# Dedza                                    21698           347951
# Ntcheu                                   18617           265988
# Mangochi                                 29499           499384
# Machinga                                 18510           290132
# Chiradzulu                                9120           150650
# Mwanza                                    5271          49553.3
# Thyolo                                   10411           312515
# Mulanje                                  17235           270906
# Phalombe                                 12029           179534
# Chikwawa                                 13949           265341
# Nsanje                                    7573           131921
# Balaka                                   12629           192267
# Neno                                      4518            78083
# Mzimba South                           5927.25           221620
# Blantyre - combined                      20657           723151
# Zomba - combined                         19042           395576
# Lilongwe - combined                      58991          1333365
# Mzimba North - combined                17781.8           355240
#
# 0                       Females 10-14 years  \
# Variable/District
# Chitipa                               14230
# Karonga                               23775
# Nkhata Bay                            17400
# Rumphi                                13199
# Likoma                                  667
# Kasungu                               56970
# Nkhotakota                            26182
# Ntchisi                               19706
# Dowa                                  48593
# Salima                                30021
# Mchinji                               40627
# Dedza                                 50753
# Ntcheu                                38544
# Mangochi                              76696
# Machinga                              47654
# Chiradzulu                            21840
# Mwanza                              6772.12
# Thyolo                                46805
# Mulanje                               40683
# Phalombe                              29352
# Chikwawa                              36051
# Nsanje                                19460
# Balaka                                28641
# Neno                                  10362
# Mzimba South                          31378
# Blantyre - combined                   82290
# Zomba - combined                      56052
# Lilongwe - combined                  168272
# Mzimba North - combined               45117
#
# 0                       Proportion who suffered incidence of sickness in past 2 weeks  \
# Variable/District
# Chitipa                                                               15.4
# Karonga                                                               14.2
# Nkhata Bay                                                            24.2
# Rumphi                                                                20.9
# Likoma                                                                18.9
# Kasungu                                                               30.5
# Nkhotakota                                                            19.7
# Ntchisi                                                                5.8
# Dowa                                                                  32.9
# Salima                                                                22.8
# Mchinji                                                                 37
# Dedza                                                                 37.2
# Ntcheu                                                                33.4
# Mangochi                                                              19.2
# Machinga                                                              24.7
# Chiradzulu                                                            19.3
# Mwanza                                                                23.7
# Thyolo                                                                24.1
# Mulanje                                                               21.9
# Phalombe                                                              19.2
# Chikwawa                                                              30.6
# Nsanje                                                                34.8
# Balaka                                                                  22
# Neno                                                                  25.3
# Mzimba South                                                          29.2
# Blantyre - combined                                                 17.235
# Zomba - combined                                                   28.9349
# Lilongwe - combined                                                25.8132
# Mzimba North - combined                                            28.4873
#
# 0                       Of those who suffered sickness proportion who suffered fever or malaria  \
# Variable/District
# Chitipa                                                               32.4
# Karonga                                                               38.9
# Nkhata Bay                                                            46.6
# Rumphi                                                                40.6
# Likoma                                                                28.7
# Kasungu                                                               35.7
# Nkhotakota                                                            47.4
# Ntchisi                                                               44.9
# Dowa                                                                  41.3
# Salima                                                                50.4
# Mchinji                                                               45.2
# Dedza                                                                 47.8
# Ntcheu                                                                40.1
# Mangochi                                                              42.7
# Machinga                                                                44
# Chiradzulu                                                            41.6
# Mwanza                                                                52.1
# Thyolo                                                                48.8
# Mulanje                                                               43.8
# Phalombe                                                              47.9
# Chikwawa                                                              50.3
# Nsanje                                                                45.4
# Balaka                                                                50.5
# Neno                                                                  57.4
# Mzimba South                                                          43.8
# Blantyre - combined                                                42.3267
# Zomba - combined                                                    46.783
# Lilongwe - combined                                                50.3069
# Mzimba North - combined                                            43.0855
#
# 0                       Population >15 Population 0-4 Children <5  \
# Variable/District
# Chitipa                         119004          47023       47023
# Karonga                         196199          67270       67270
# Nkhata Bay                      165232          52032       52032
# Rumphi                          124836          40266       40266
# Likoma                            6209           1620        1620
# Kasungu                         477107         182597      182597
# Nkhotakota                      219550          78570       78570
# Ntchisi                         158415          63857       63857
# Dowa                            459614         167897      167897
# Salima                          236914          87054       87054
# Mchinji                         335857         129180      129180
# Dedza                           422050         141877      141877
# Ntcheu                          324404         115253      115253
# Mangochi                        592827         208837      208837
# Machinga                        343492         124005      124005
# Chiradzulu                      185742          54623       54623
# Mwanza                         58817.2        19768.4     19768.4
# Thyolo                          379794         113801      113801
# Mulanje                         331426          99198       99198
# Phalombe                        213771          71570       71570
# Chikwawa                        313959         105321      105321
# Nsanje                          159833          57226       57226
# Balaka                          231923          80303       80303
# Neno                             92648          34100       34100
# Mzimba South                    267772        85996.5     85996.5
# Blantyre - combined             822915         231255      231255
# Zomba - combined                472794         151449      151449
# Lilongwe - combined            1539041         497111      497111
# Mzimba North - combined         416736         138186      138186
#
# 0                                 ...            Total population >15  \
# Variable/District                 ...
# Chitipa                           ...                          119004
# Karonga                           ...                          196199
# Nkhata Bay                        ...                          165232
# Rumphi                            ...                          124836
# Likoma                            ...                            6209
# Kasungu                           ...                          477107
# Nkhotakota                        ...                          219550
# Ntchisi                           ...                          158415
# Dowa                              ...                          459614
# Salima                            ...                          236914
# Mchinji                           ...                          335857
# Dedza                             ...                          422050
# Ntcheu                            ...                          324404
# Mangochi                          ...                          592827
# Machinga                          ...                          343492
# Chiradzulu                        ...                          185742
# Mwanza                            ...                         58817.2
# Thyolo                            ...                          379794
# Mulanje                           ...                          331426
# Phalombe                          ...                          213771
# Chikwawa                          ...                          313959
# Nsanje                            ...                          159833
# Balaka                            ...                          231923
# Neno                              ...                           92648
# Mzimba South                      ...                          267772
# Blantyre - combined               ...                          822915
# Zomba - combined                  ...                          472794
# Lilongwe - combined               ...                         1539041
# Mzimba North - combined           ...                          416736
#
# 0                       Total population <15 Proportion chronically ill  \
# Variable/District
# Chitipa                               115793                          3
# Karonga                               174172                          5
# Nkhata Bay                            131119                        5.8
# Rumphi                                101085                          6
# Likoma                                  4285                        7.9
# Kasungu                               450437                        5.4
# Nkhotakota                            197523                        4.7
# Ntchisi                               157475                        5.1
# Dowa                                  406600                        5.3
# Salima                                221440                        8.5
# Mchinji                               319574                        5.8
# Dedza                                 366143                        8.7
# Ntcheu                                295667                        4.4
# Mangochi                              538550                        3.6
# Machinga                              324741                          8
# Chiradzulu                            145757                        6.6
# Mwanza                               50124.5                        4.7
# Thyolo                                299370                          9
# Mulanje                               264095                        7.9
# Phalombe                              190181                        4.7
# Chikwawa                              269501                        7.6
# Nsanje                                143679                        8.1
# Balaka                                205014                        7.8
# Neno                                   80801                        5.8
# Mzimba South                          222417                        6.3
# Blantyre - combined                   598738                    6.91076
# Zomba - combined                      391091                    9.12349
# Lilongwe - combined                  1252537                     6.3824
# Mzimba North - combined               344847                        6.3
#
# 0                       Of those chronically ill proportion with mental illness  \
# Variable/District
# Chitipa                                                                  6
# Karonga                                                                7.7
# Nkhata Bay                                                             4.7
# Rumphi                                                                 3.7
# Likoma                                                                 8.8
# Kasungu                                                                6.2
# Nkhotakota                                                             1.2
# Ntchisi                                                                3.7
# Dowa                                                                   5.2
# Salima                                                                   4
# Mchinji                                                                4.8
# Dedza                                                                  7.2
# Ntcheu                                                                 3.2
# Mangochi                                                                 5
# Machinga                                                               2.4
# Chiradzulu                                                             2.3
# Mwanza                                                                 2.5
# Thyolo                                                                 1.6
# Mulanje                                                                  2
# Phalombe                                                               3.1
# Chikwawa                                                               1.9
# Nsanje                                                                 1.5
# Balaka                                                                 7.8
# Neno                                                                   3.5
# Mzimba South                                                           8.3
# Blantyre - combined                                                 3.4086
# Zomba - combined                                                  0.384502
# Lilongwe - combined                                                5.25045
# Mzimba North - combined                                            6.37569
#
# 0                       Of those chronically ill proportion with Epilepsy  \
# Variable/District
# Chitipa                                                               5.5
# Karonga                                                               3.3
# Nkhata Bay                                                            2.5
# Rumphi                                                                6.5
# Likoma                                                                5.3
# Kasungu                                                                 3
# Nkhotakota                                                            3.7
# Ntchisi                                                              10.6
# Dowa                                                                  3.7
# Salima                                                                  2
# Mchinji                                                              21.3
# Dedza                                                                 0.3
# Ntcheu                                                                4.7
# Mangochi                                                             14.4
# Machinga                                                              5.6
# Chiradzulu                                                            3.8
# Mwanza                                                                4.1
# Thyolo                                                                7.3
# Mulanje                                                               7.6
# Phalombe                                                              8.9
# Chikwawa                                                              7.4
# Nsanje                                                                1.3
# Balaka                                                                4.9
# Neno                                                                  2.3
# Mzimba South                                                          8.2
# Blantyre - combined                                               2.48737
# Zomba - combined                                                  3.84649
# Lilongwe - combined                                                4.5686
# Mzimba North - combined                                           5.45607
#
# 0                       Population >5 Total EHP Cost  \
# Variable/District
# Chitipa                        187774    1.55825e+06
# Karonga                        303101    3.39464e+06
# Nkhata Bay                     244319    2.75016e+06
# Rumphi                         185655    1.98456e+06
# Likoma                           8874         100550
# Kasungu                        744947    7.17356e+06
# Nkhotakota                     338503    3.60211e+06
# Ntchisi                        252033     2.0034e+06
# Dowa                           698317    6.73101e+06
# Salima                         371300    4.20407e+06
# Mchinji                        526251    6.17853e+06
# Dedza                          646316    7.21214e+06
# Ntcheu                         504818    6.08363e+06
# Mangochi                       922540    1.13252e+07
# Machinga                       544228    6.72148e+06
# Chiradzulu                     276876      4.081e+06
# Mwanza                        89173.2    1.15253e+06
# Thyolo                         565363    8.44831e+06
# Mulanje                        496323    8.15741e+06
# Phalombe                       332382    4.83242e+06
# Chikwawa                       478139    6.61718e+06
# Nsanje                         246286    3.65023e+06
# Balaka                         356634    4.57888e+06
# Neno                           139349    2.01872e+06
# Mzimba South                   404192    4.25691e+06
# Blantyre - combined           1190398    1.93434e+07
# Zomba - combined               712436    1.06944e+07
# Lilongwe - combined           2294467    2.86115e+07
# Mzimba North - combined        623397    7.69813e+06
#
# 0                       Total EHP Cost (less donor contributions) - using RM program data  \
# Variable/District
# Chitipa                                                             334847
# Karonga                                                             573116
# Nkhata Bay                                                          468815
# Rumphi                                                              355014
# Likoma                                                             18646.8
# Kasungu                                                        1.33351e+06
# Nkhotakota                                                          612358
# Ntchisi                                                             454285
# Dowa                                                           1.30905e+06
# Salima                                                              712005
# Mchinji                                                             990212
# Dedza                                                           1.2862e+06
# Ntcheu                                                              941028
# Mangochi                                                       1.72784e+06
# Machinga                                                       1.00791e+06
# Chiradzulu                                                          537396
# Mwanza                                                              166053
# Thyolo                                                          1.0616e+06
# Mulanje                                                             971582
# Phalombe                                                            615917
# Chikwawa                                                            890044
# Nsanje                                                              461968
# Balaka                                                              707374
# Neno                                                                266456
# Mzimba South                                                        786522
# Blantyre - combined                                            2.12944e+06
# Zomba - combined                                               1.33551e+06
# Lilongwe - combined                                            4.33346e+06
# Mzimba North - combined                                        1.19092e+06
#
# 0                       Total EHP Cost (less donor contributions) - using RM district data  \
# Variable/District
# Chitipa                                                             332611
# Karonga                                                             711319
# Nkhata Bay                                                          967195
# Rumphi                                                              939625
# Likoma                                                             20999.8
# Kasungu                                                        2.13013e+06
# Nkhotakota                                                     1.04579e+06
# Ntchisi                                                        1.15572e+06
# Dowa                                                           2.59794e+06
# Salima                                                         1.42964e+06
# Mchinji                                                        2.32861e+06
# Dedza                                                          1.57475e+06
# Ntcheu                                                         2.33857e+06
# Mangochi                                                       2.81429e+06
# Machinga                                                       1.52291e+06
# Chiradzulu                                                     1.52516e+06
# Mwanza                                                              289609
# Thyolo                                                         2.60091e+06
# Mulanje                                                        2.27406e+06
# Phalombe                                                         1.945e+06
# Chikwawa                                                       1.61366e+06
# Nsanje                                                         1.29971e+06
# Balaka                                                         1.44878e+06
# Neno                                                                369650
# Mzimba South                                                   1.91233e+06
# Blantyre - combined                                            4.14205e+06
# Zomba - combined                                                 2.328e+06
# Lilongwe - combined                                            8.30406e+06
# Mzimba North - combined                                        3.31833e+06
#
# 0                                       District
# Variable/District
# Chitipa                                  Chitipa
# Karonga                                  Karonga
# Nkhata Bay                            Nkhata Bay
# Rumphi                                    Rumphi
# Likoma                                    Likoma
# Kasungu                                  Kasungu
# Nkhotakota                            Nkhotakota
# Ntchisi                                  Ntchisi
# Dowa                                        Dowa
# Salima                                    Salima
# Mchinji                                  Mchinji
# Dedza                                      Dedza
# Ntcheu                                    Ntcheu
# Mangochi                                Mangochi
# Machinga                                Machinga
# Chiradzulu                            Chiradzulu
# Mwanza                                    Mwanza
# Thyolo                                    Thyolo
# Mulanje                                  Mulanje
# Phalombe                                Phalombe
# Chikwawa                                Chikwawa
# Nsanje                                    Nsanje
# Balaka                                    Balaka
# Neno                                        Neno
# Mzimba South                        Mzimba South
# Blantyre - combined          Blantyre - combined
# Zomba - combined                Zomba - combined
# Lilongwe - combined          Lilongwe - combined
# Mzimba North - combined  Mzimba North - combined
#
# [29 rows x 26 columns]

# %%
## Generate dataframes consisting of independent variables and dependent variable 

x = df.dropna(how='all')
x = x.drop('Total EHP Cost',1)
x = x.drop('District',1) # Variable/District under V1
#x = x.drop('Total EHP Cost (less donor contributions)',1)
#x = x.drop('Total EHP Cost (HIV prevalence adjusted)',1)
x = x.drop('Total EHP Cost (less donor contributions) - using RM program data',1)
x = x.drop('Total EHP Cost (less donor contributions) - using RM district data',1)

y = df['Total EHP Cost']
y = y.dropna()
y_lessdonor = df['Total EHP Cost (less donor contributions) - using RM program data']
y_lessdonor = y_lessdonor.dropna()
y_lessdonor_rmdist = df['Total EHP Cost (less donor contributions) - using RM district data']
y_lessdonor_rmdist = y_lessdonor_rmdist.dropna()

## Convert values to numeric
x = x.apply(pd.to_numeric, errors = 'coerce')
y = y.apply(pd.to_numeric, errors = 'coerce')
y_lessdonor = y_lessdonor.apply(pd.to_numeric, errors = 'coerce')
y_lessdonor_rmdist = y_lessdonor_rmdist.apply(pd.to_numeric, errors = 'coerce')
x.describe()
for col in x.columns:
    print(col)
# Out:
# Females 15-49
# Women age 15-49 currently pregnant (%)
# Lives births (amended)
# Population 15-49
# Females 10-14 years
# Proportion who suffered incidence of sickness in past 2 weeks
# Of those who suffered sickness proportion who suffered fever or malaria
# Population >15
# Population 0-4
# Children <5
# Propotion of children <5 -3 SD below weight-for-age
# Children <15
# Proportion of children aged 6-23 months fed minimum dietary diversity
# HIV prevalence among 15-49 (%)
# Total Population
# Population >40
# Total population >15
# Total population <15
# Proportion chronically ill
# Of those chronically ill proportion with mental illness
# Of those chronically ill proportion with Epilepsy
# Population >5

# %%
## Validation
    # Total EHP Cost (HIV Prevalence adjusted) = 185,164,299
    # Total EHP Cost (less donor contributions) (HIV Prevalence adjusted) = 53,653,998
print(y.sum(skipna = True), "should be equal to 185,164,299")
print(y_lessdonor.sum(skipna = True), "should be equal to 53,653,998") 
if (-2 < y.sum(skipna = True) - 185164299 < 2) & (-2 < y_lessdonor.sum(skipna = True)-53653998 <2):
    print("VERIFIED")
else:
    print("ERROR IN DATA")
# Out:
# 185164299.70839068 should be equal to 185,164,299
# 27579087.181493983 should be equal to 53,653,998
# ERROR IN DATA

# %%
### 3) DESCRIPTIVE ANALYSIS
######################################################################

## CORRELATION BETWEEN INDEPENDENT VARIABLES

# Re-order columns for correlation matrix:
columnsTitles = ['Total Population', 'Population >40', 'Females 15-49','Population 15-49',
                 'Total population >15','Population >15','Total population <15','Children <15','Females 10-14 years',
                 'Population >5','Population 0-4','Children <5','Lives births (amended)','Women age 15-49 currently pregnant (%)',
                 'Proportion who suffered incidence of sickness in past 2 weeks','Of those who suffered sickness proportion who suffered fever or malaria',
                 'Propotion of children <5 -3 SD below weight-for-age','Proportion of children aged 6-23 months fed minimum dietary diversity',
                 'HIV prevalence among 15-49 (%)','Proportion chronically ill','Of those chronically ill proportion with mental illness',
                 'Of those chronically ill proportion with Epilepsy',]
x = x.reindex(columns=columnsTitles)

#Store correlation matrix in an excel workbook
corr = x.corr()
(corr.style.background_gradient(cmap='coolwarm')).set_precision(2).to_excel("corr_matrix.xlsx", engine="openpyxl")

# Print correlation matrix
x.corr()
(corr.style.background_gradient(cmap='coolwarm')).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col0 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col1 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col2 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col3 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col4 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col5 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col6 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col7 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col8 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col9 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col10 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col11 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col12 {
#             background-color:  #c43032;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col13 {
#             background-color:  #84a7fc;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col14 {
#             background-color:  #a7c5fe;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col15 {
#             background-color:  #bbd1f8;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col16 {
#             background-color:  #7295f4;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col17 {
#             background-color:  #abc8fd;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col18 {
#             background-color:  #bad0f8;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col19 {
#             background-color:  #93b5fe;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col20 {
#             background-color:  #aac7fd;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row0_col21 {
#             background-color:  #88abfd;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col0 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col1 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col2 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col3 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col4 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col5 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col6 {
#             background-color:  #b50927;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col7 {
#             background-color:  #b50927;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col8 {
#             background-color:  #b50927;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col9 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col10 {
#             background-color:  #b50927;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col11 {
#             background-color:  #b50927;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col12 {
#             background-color:  #c43032;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col13 {
#             background-color:  #7ea1fa;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col14 {
#             background-color:  #abc8fd;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col15 {
#             background-color:  #bed2f6;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col16 {
#             background-color:  #7699f6;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col17 {
#             background-color:  #abc8fd;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col18 {
#             background-color:  #c0d4f5;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col19 {
#             background-color:  #9bbcff;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col20 {
#             background-color:  #a7c5fe;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row1_col21 {
#             background-color:  #82a6fb;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col0 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col1 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col2 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col3 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col4 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col5 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col6 {
#             background-color:  #b50927;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col7 {
#             background-color:  #b50927;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col8 {
#             background-color:  #b50927;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col9 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col10 {
#             background-color:  #b50927;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col11 {
#             background-color:  #b50927;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col12 {
#             background-color:  #c73635;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col13 {
#             background-color:  #7ea1fa;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col14 {
#             background-color:  #a2c1ff;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col15 {
#             background-color:  #bcd2f7;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col16 {
#             background-color:  #7597f6;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col17 {
#             background-color:  #adc9fd;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col18 {
#             background-color:  #c1d4f4;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col19 {
#             background-color:  #97b8ff;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col20 {
#             background-color:  #a9c6fd;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row2_col21 {
#             background-color:  #84a7fc;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row3_col0 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row3_col1 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row3_col2 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row3_col3 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row3_col4 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row3_col5 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row3_col6 {
#             background-color:  #b50927;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row3_col7 {
#             background-color:  #b50927;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row3_col8 {
#             background-color:  #b70d28;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40f2427bc15row3_col9 {
#             background-color:  #b40426;
#         }    #T_af1eb462_6f85_11ea_8d0a_f40

# %%
# Based on the correlation matrix, drop superfluous population variables which are highly correlated with total population

x_totpop = x.drop('Females 15-49',1)
x_totpop = x_totpop.drop('Population 15-49',1)
x_totpop = x_totpop.drop('Females 10-14 years',1)
x_totpop = x_totpop.drop('Population >15',1)
x_totpop = x_totpop.drop('Population 0-4',1)
x_totpop = x_totpop.drop('Children <5',1)
x_totpop = x_totpop.drop('Children <15',1)
x_totpop = x_totpop.drop('Population >40',1)
x_totpop = x_totpop.drop('Total population >15',1)
x_totpop = x_totpop.drop('Total population <15',1)
x_totpop = x_totpop.drop('Population >5',1)
x_totpop = x_totpop.drop('Lives births (amended)',1)

# %%
### 4) PREPRATION FOR DIMENSION REDUCTION
######################################################################

## Log values

# Indenpendent variables
x_totpop_ln = x_totpop.copy()
for col in x_totpop.columns:
    x_totpop_ln[col] = np.log(x_totpop_ln[col])
    
# Dependent variables
y_ln = y.copy()
y_ln = np.log(y_ln)

y_lessdonor_ln = y_lessdonor.copy()
y_lessdonor_ln = np.log(y_lessdonor_ln)

y_lessdonor_rmdist_ln = y_lessdonor_rmdist.copy()
y_lessdonor_rmdist_ln = np.log(y_lessdonor_rmdist_ln)

# %%
### 5) DIMENSION REDUCTION
######################################################################

## 5.i) Recursive feature selection
######################################################################
# Reference: https://towardsdatascience.com/feature-selection-with-pandas-e3690ad8504b

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE

# Calculate the optimum number of features in the total EHP cost model
######################################################################
nof_list=np.arange(1,11)            
high_score=0
#Variable to store the optimum features
nof=0           
score_list =[]
for n in range(len(nof_list)):
    X_train, X_test, y_train, y_test = train_test_split(x_totpop_ln,y_ln, test_size = 0.3, random_state = 0)
    model = LinearRegression()
    rfe = RFE(model,nof_list[n])
    X_train_rfe = rfe.fit_transform(X_train,y_train)
    X_test_rfe = rfe.transform(X_test)
    model.fit(X_train_rfe,y_train)
    score = model.score(X_test_rfe,y_test)
    score_list.append(score)
    if(score>high_score):
        high_score = score
        nof = nof_list[n]
print("Optimum number of features (Total EHP Cost): %d" %nof)
print("Score with %d features (Total EHP Cost): %f" % (nof, high_score))

# Calculate the optimum number of features in the total EHP cost less donor contributions model
###############################################################################################
nof_list=np.arange(1,11)            
high_score=0
#Variable to store the optimum features
nof=0           
score_list =[]
for n in range(len(nof_list)):
    X_train, X_test, y_train, y_test = train_test_split(x_totpop_ln,y_lessdonor_ln, test_size = 0.3, random_state = 0)
    model = LinearRegression()
    rfe = RFE(model,nof_list[n])
    X_train_rfe = rfe.fit_transform(X_train,y_train)
    X_test_rfe = rfe.transform(X_test)
    model.fit(X_train_rfe,y_train)
    score = model.score(X_test_rfe,y_test)
    score_list.append(score)
    if(score>high_score):
        high_score = score
        nof = nof_list[n]
print("Optimum number of features (Total EHP Cost less donors): %d" %nof)
print("Score with %d features (Total EHP Cost less donors): %f" % (nof, high_score))

# Calculate the optimum number of features in the total EHP cost less donor contributions model
###############################################################################################
nof_list=np.arange(1,11)            
high_score=0
#Variable to store the optimum features
nof=0           
score_list =[]
for n in range(len(nof_list)):
    X_train, X_test, y_train, y_test = train_test_split(x_totpop_ln,y_lessdonor_rmdist_ln, test_size = 0.3, random_state = 0)
    model = LinearRegression()
    rfe = RFE(model,nof_list[n])
    X_train_rfe = rfe.fit_transform(X_train,y_train)
    X_test_rfe = rfe.transform(X_test)
    model.fit(X_train_rfe,y_train)
    score = model.score(X_test_rfe,y_test)
    score_list.append(score)
    if(score>high_score):
        high_score = score
        nof = nof_list[n]
print("Optimum number of features (Total EHP Cost less donors (using RM district data)): %d" %nof)
print("Score with %d features (Total EHP Cost less donors(using RM district data)): %f" % (nof, high_score))
# Out:
# Optimum number of features (Total EHP Cost): 3
# Score with 3 features (Total EHP Cost): 0.993261
# Optimum number of features (Total EHP Cost less donors): 2
# Score with 2 features (Total EHP Cost less donors): 0.997726
# Optimum number of features (Total EHP Cost less donors (using RM district data)): 7
# Score with 7 features (Total EHP Cost less donors(using RM district data)): 0.874859

# %%
## 5.ii) Backward Elimination based on p-value
######################################################################

# Find an efficient set of features in the total EHP cost model
######################################################################
cols = list(x_totpop_ln.columns)
pmax = 1
while (len(cols)>0):
    p= []
    X_1 = x_totpop_ln[cols]
    X_1 = sm.add_constant(X_1)
    model = sm.OLS(y_ln,X_1).fit()
    p = pd.Series(model.pvalues.values[1:],index = cols)      
    pmax = max(p)
    feature_with_p_max = p.idxmax()
    if(pmax>0.05):
        cols.remove(feature_with_p_max)
    else:
        break
selected_features_BE = cols
print("Selected features (Total EHP Cost)", selected_features_BE)

# Find an efficient set of features in the total EHP cost less donor contributions model
###############################################################################################
pmax = 1
while (len(cols)>0):
    p= []
    X_1 = x_totpop_ln[cols]
    X_1 = sm.add_constant(X_1)
    model = sm.OLS(y_lessdonor_ln,X_1).fit()
    p = pd.Series(model.pvalues.values[1:],index = cols)      
    pmax = max(p)
    feature_with_p_max = p.idxmax()
    if(pmax>0.05):
        cols.remove(feature_with_p_max)
    else:
        break
selected_features_BE = cols
print("Selected features (Total EHP Cost less donor contributions) (using RM program data)", selected_features_BE)

# Find an efficient set of features in the total EHP cost less donor contributions model
###############################################################################################
pmax = 1
while (len(cols)>0):
    p= []
    X_1 = x_totpop_ln[cols]
    X_1 = sm.add_constant(X_1)
    model = sm.OLS(y_lessdonor_rmdist_ln,X_1).fit()
    p = pd.Series(model.pvalues.values[1:],index = cols)      
    pmax = max(p)
    feature_with_p_max = p.idxmax()
    if(pmax>0.05):
        cols.remove(feature_with_p_max)
    else:
        break
selected_features_BE = cols
print("Selected features (Total EHP Cost less donor contributions) (using RM district data)", selected_features_BE)
# Out:
# Selected features (Total EHP Cost) ['Total Population', 'Proportion who suffered incidence of sickness in past 2 weeks', 'HIV prevalence among 15-49 (%)', 'Proportion chronically ill']
# Selected features (Total EHP Cost less donor contributions) (using RM program data) ['Total Population', 'Proportion chronically ill']
# Selected features (Total EHP Cost less donor contributions) (using RM district data) ['Total Population']

# %%
## 5.iii) Backward Elimination based on AIC (Constant introduced in exogeneous matrix)
######################################################################

## Total EHP Cost Model
######################################################################
true_values = y_ln
cols = list(x_totpop_ln.columns)
pmax = 1
while (len(cols)>0):
    p= []
    
    X_1 = x_totpop_ln[cols]
    X_1 = sm.add_constant(X_1)
    k = np.shape(X_1)[1]
    n_obs = np.shape(X_1)[0]
    model = sm.OLS(true_values,X_1).fit()
    
    p = pd.Series(model.pvalues.values[1:],index = cols)   
    r2 = model.rsquared
    pmax = max(p)
    feature_with_p_max = p.idxmax()

    predicted_values = model.predict()
    sumofresiduals = sum(np.array([(predicted_values[xi]-true_values[xi])**2 for xi in range(1,n_obs)]))
    aic_old = n_obs*math.log(sumofresiduals/n_obs) + 2*k
    
    aic_new = aic_old
    iter = 0
    
    while (aic_new <= aic_old):
        iter = iter + 1 
        print('Iteration',iter)
        
        aic_old = aic_new
        cols.remove(feature_with_p_max)
        print("Variable dropped:", feature_with_p_max,"; p-value of variable:", pmax)
        print("OLD AIC:", aic_old)
        
        X_1 = x_totpop_ln[cols]
        X_1 = sm.add_constant(X_1)
        k = np.shape(X_1)[1]
        print("Degrees of freedom:", k)
        model = sm.OLS(true_values,X_1).fit()

        p = pd.Series(model.pvalues.values[1:],index = cols)   
        r2 = model.rsquared
        pmax = max(p)
        feature_with_p_max = p.idxmax()

        predicted_values = model.predict()
        sumofresiduals = sum(np.array([(predicted_values[xi]-true_values[xi])**2 for xi in range(1,n_obs)]))
        aic_new = n_obs*math.log(sumofresiduals/n_obs) + 2*k
        print("NEW AIC:", aic_new)
    else:
        break
selected_features_BE = cols
print(selected_features_BE)
print(model.summary())

## Total EHP Cost less donor contributions Model
######################################################################
true_values = y_lessdonor_ln
cols = list(x_totpop_ln.columns)
pmax = 1
while (len(cols)>0):
    p= []
    
    X_1 = x_totpop_ln[cols]
    X_1 = sm.add_constant(X_1)
    k = np.shape(X_1)[1]
    n_obs = np.shape(X_1)[0]
    model = sm.OLS(true_values,X_1).fit()

    p = pd.Series(model.pvalues.values[1:],index = cols)   
    r2 = model.rsquared
    pmax = max(p)
    feature_with_p_max = p.idxmax()

    predicted_values = model.predict()
    sumofresiduals = sum(np.array([(predicted_values[xi]-true_values[xi])**2 for xi in range(1,n_obs)]))
    aic_old = n_obs*math.log(sumofresiduals/n_obs) + 2*k
    
    aic_new = aic_old
    iter = 0
    
    while (aic_new <= aic_old):
        iter = iter + 1 
        print('Iteration',iter)
        
        aic_old = aic_new
        cols.remove(feature_with_p_max)
        print("Variable dropped:", feature_with_p_max,"; p-value of variable:", pmax)
        print("OLD AIC:", aic_old)
        
        X_1 = x_totpop_ln[cols]
        X_1 = sm.add_constant(X_1)
        k = np.shape(X_1)[1]
        print("Degrees of freedom:", k)
        model = sm.OLS(true_values,X_1).fit()

        p = pd.Series(model.pvalues.values[1:],index = cols)   
        r2 = model.rsquared
        pmax = max(p)
        feature_with_p_max = p.idxmax()

        predicted_values = model.predict()
        sumofresiduals = sum(np.array([(predicted_values[xi]-true_values[xi])**2 for xi in range(1,n_obs)]))
        aic_new = n_obs*math.log(sumofresiduals/n_obs) + 2*k
        print("NEW AIC:", aic_new)
    else:
        break
selected_features_BE = cols
print(selected_features_BE)
print(model.summary())
# Out:
# Iteration 1
# Variable dropped: Of those chronically ill proportion with Epilepsy ; p-value of variable: 0.9281424900075858
# OLD AIC: -141.36791556594324
# Degrees of freedom: 10
# NEW AIC: -143.3583910621089
# Iteration 2
# Variable dropped: Propotion of children <5 -3 SD below weight-for-age ; p-value of variable: 0.8935774177887011
# OLD AIC: -143.3583910621089
# Degrees of freedom: 9
# NEW AIC: -145.25397696825976
# Iteration 3
# Variable dropped: Of those chronically ill proportion with mental illness ; p-value of variable: 0.401371402676477
# OLD AIC: -145.25397696825976
# Degrees of freedom: 8
# NEW AIC: -145.53688309412516
# Iteration 4
# Variable dropped: Women age 15-49 currently pregnant (%) ; p-value of variable: 0.2338881422926432
# OLD AIC: -145.53688309412516
# Degrees of freedom: 7
# NEW AIC: -145.3228878164737
# ['Total Population', 'Proportion who suffered incidence of sickness in past 2 weeks', 'Of those who suffered sickness proportion who suffered fever or malaria', 'Proportion of children aged 6-23 months fed minimum dietary diversity', 'HIV prevalence among 15-49 (%)', 'Proportion chronically ill']
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Total EHP Cost   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                     853.3
# Date:                Wed, 26 Feb 2020   Prob (F-statistic):           6.80e-25
# Time:                        15:18:55   Log-Likelihood:                 37.876
# No. Observations:                  29   AIC:                            -61.75
# Df Residuals:                      22   BIC:                            -52.18
# Df Model:                           6
# Covariance Type:            nonrobust
# ===========================================================================================================================================
#                                                                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                       0.5430      0.396      1.370      0.184      -0.279       1.365
# Total Population                                                            0.9967      0.016     61.596      0.000       0.963       1.030
# Proportion who suffered incidence of sickness in past 2 weeks               0.1563      0.043      3.621      0.002       0.067       0.246
# Of those who suffered sickness proportion who suffered fever or malaria     0.1869      0.117      1.598      0.124      -0.056       0.430
# Proportion of children aged 6-23 months fed minimum dietary diversity      -0.0696      0.057     -1.221      0.235      -0.188       0.049
# HIV prevalence among 15-49 (%)                                              0.2768      0.028      9.921      0.000       0.219       0.335
# Proportion chronically ill                                                  0.1515      0.059      2.573      0.017       0.029       0.274
# ==============================================================================
# Omnibus:                        4.101   Durbin-Watson:                   1.596
# Prob(Omnibus):                  0.129   Jarque-Bera (JB):                2.942
# Skew:                           0.773   Prob(JB):                        0.230
# Kurtosis:                       3.206   Cond. No.                         423.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Iteration 1
# Variable dropped: Proportion of children aged 6-23 months fed minimum dietary diversity ; p-value of variable: 0.886679924412097
# OLD AIC: -195.24298966179055
# Degrees of freedom: 10
# NEW AIC: -197.17953611330378
# Iteration 2
# Variable dropped: Of those chronically ill proportion with Epilepsy ; p-value of variable: 0.8277862149833722
# OLD AIC: -197.17953611330378
# Degrees of freedom: 9
# NEW AIC: -199.1144756672481
# Iteration 3
# Variable dropped: Of those who suffered sickness proportion who suffered fever or malaria ; p-value of variable: 0.5979582217941918
# OLD AIC: -199.1144756672481
# Degrees of freedom: 8
# NEW AIC: -200.61717657606096
# Iteration 4
# Variable dropped: Propotion of children <5 -3 SD below weight-for-age ; p-value of variable: 0.6594371631271873
# OLD AIC: -200.61717657606096
# Degrees of freedom: 7
# NEW AIC: -202.42848104511782
# Iteration 5
# Variable dropped: Women age 15-49 currently pregnant (%) ; p-value of variable: 0.6894675585315416
# OLD AIC: -202.42848104511782
# Degrees of freedom: 6
# NEW AIC: -204.24765499828857
# Iteration 6
# Variable dropped: Proportion who suffered incidence of sickness in past 2 weeks ; p-value of variable: 0.13147530701196325
# OLD AIC: -204.24765499828857
# Degrees of freedom: 5
# NEW AIC: -203.41218489026934
# ['Total Population', 'HIV prevalence among 15-49 (%)', 'Proportion chronically ill', 'Of those chronically ill proportion with mental illness']
#                                                     OLS Regression Results
# =============================================================================================================================
# Dep. Variable:     Total EHP Cost (less donor contributions) - using RM program data   R-squared:                       0.999
# Model:                                                                           OLS   Adj. R-squared:                  0.999
# Method:                                                                Least Squares   F-statistic:                     8282.
# Date:                                                               Wed, 26 Feb 2020   Prob (F-statistic):           2.69e-37
# Time:                                                                       15:18:55   Log-Likelihood:                 65.416
# No. Observations:                                                                 29   AIC:                            -120.8
# Df Residuals:                                                                     24   BIC:                            -114.0
# Df Model:                                                                          4
# Covariance Type:                                                           nonrobust
# ===========================================================================================================================
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# const                                                       0.3872      0.088      4.376      0.000       0.205       0.570
# Total Population                                            0.9825      0.005    179.943      0.000       0.971       0.994
# HIV prevalence among 15-49 (%)                              0.0258      0.011      2.260      0.033       0.002       0.049
# Proportion chronically ill                                  0.1021      0.020      5.184      0.000       0.061       0.143
# Of those chronically ill proportion with mental illness     0.0315      0.009      3.441      0.002       0.013       0.050
# ==============================================================================
# Omnibus:                        1.605   Durbin-Watson:                   2.470
# Prob(Omnibus):                  0.448   Jarque-Bera (JB):                1.332
# Skew:                          -0.353   Prob(JB):                        0.514
# Kurtosis:                       2.223   Cond. No.                         231.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
## 5.iii) Backward Elimination based on AIC (No constant in exogeneous matrix + Robust Model)

## Currently ERROR : becuase the pvalue array does not seem to be stored after running RLM
######################################################################


## Total EHP Cost Model
######################################################################
true_values = y_ln
cols = list(x_totpop_ln.columns)
pmax = 1
while (len(cols)>0):
    p= []
    
    X_1 = x_totpop_ln[cols]
    #X_1 = sm.add_constant(X_1)
    k = np.shape(X_1)[1]
    n_obs = np.shape(X_1)[0]
    model = sm.OLS(true_values,X_1).fit()
    #model = sm.RLM(true_values, X_1, M=sm.robust.norms.HuberT())

    p = pd.Series(model.pvalues.values[0:],index = cols)   
    r2 = model.rsquared
    pmax = max(p)
    feature_with_p_max = p.idxmax()

    predicted_values = model.predict()
    sumofresiduals = sum(np.array([(predicted_values[xi]-true_values[xi])**2 for xi in range(1,n_obs)]))
    aic_old = n_obs*math.log(sumofresiduals/n_obs) + 2*k
    
    aic_new = aic_old
    iter = 0
    
    while (aic_new <= aic_old):
        iter = iter + 1 
        print('Iteration',iter)
        
        aic_old = aic_new
        cols.remove(feature_with_p_max)
        print("Variable dropped:", feature_with_p_max,"; p-value of variable:", pmax)
        print("OLD AIC:", aic_old)
        
        X_1 = x_totpop_ln[cols]
        #X_1 = sm.add_constant(X_1)
        k = np.shape(X_1)[1]
        print("Degrees of freedom:", k)
        model = sm.OLS(true_values,X_1).fit()
        #model = sm.RLM(true_values, X_1, M=sm.robust.norms.HuberT())

        p = pd.Series(model.pvalues.values[0:],index = cols)   
        r2 = model.rsquared
        pmax = max(p)
        feature_with_p_max = p.idxmax()

        predicted_values = model.predict()
        sumofresiduals = sum(np.array([(predicted_values[xi]-true_values[xi])**2 for xi in range(1,n_obs)]))
        aic_new = n_obs*math.log(sumofresiduals/n_obs) + 2*k
        print("NEW AIC:", aic_new)
    else:
        break
selected_features_BE = cols
print(selected_features_BE)
print(model.summary())

## Total EHP Cost less donor contributions Model
######################################################################
true_values = y_lessdonor_ln
cols = list(x_totpop_ln.columns)
pmax = 1
while (len(cols)>0):
    p= []
    
    X_1 = x_totpop_ln[cols]
    #X_1 = sm.add_constant(X_1)
    k = np.shape(X_1)[1]
    n_obs = np.shape(X_1)[0]
    model = sm.OLS(true_values,X_1).fit()
    #model = sm.RLM(true_values, X_1, M=sm.robust.norms.HuberT())

    p = pd.Series(model.pvalues.values[0:],index = cols)   
    r2 = model.rsquared
    pmax = max(p)
    feature_with_p_max = p.idxmax()

    predicted_values = model.predict()
    sumofresiduals = sum(np.array([(predicted_values[xi]-true_values[xi])**2 for xi in range(1,n_obs)]))
    aic_old = n_obs*math.log(sumofresiduals/n_obs) + 2*k
    
    aic_new = aic_old
    iter = 0
    
    while (aic_new <= aic_old):
        iter = iter + 1 
        print('Iteration',iter)
        
        aic_old = aic_new
        cols.remove(feature_with_p_max)
        print("Variable dropped:", feature_with_p_max,"; p-value of variable:", pmax)
        print("OLD AIC:", aic_old)
        
        X_1 = x_totpop_ln[cols]
        #X_1 = sm.add_constant(X_1)
        k = np.shape(X_1)[1]
        print("Degrees of freedom:", k)
        model = sm.OLS(true_values,X_1).fit()
        #model = sm.RLM(true_values, X_1, M=sm.robust.norms.HuberT())

        p = pd.Series(model.pvalues.values[0:],index = cols)   
        r2 = model.rsquared
        pmax = max(p)
        feature_with_p_max = p.idxmax()

        predicted_values = model.predict()
        sumofresiduals = sum(np.array([(predicted_values[xi]-true_values[xi])**2 for xi in range(1,n_obs)]))
        aic_new = n_obs*math.log(sumofresiduals/n_obs) + 2*k
        print("NEW AIC:", aic_new)
    else:
        break
selected_features_BE = cols
print(selected_features_BE)
print(model.summary())
# Out:
# Iteration 1
# Variable dropped: Propotion of children <5 -3 SD below weight-for-age ; p-value of variable: 0.91595570494512
# OLD AIC: -142.9343789997433
# Degrees of freedom: 9
# NEW AIC: -144.8312007501951
# Iteration 2
# Variable dropped: Of those chronically ill proportion with Epilepsy ; p-value of variable: 0.8193161410882223
# OLD AIC: -144.8312007501951
# Degrees of freedom: 8
# NEW AIC: -146.78395448431425
# Iteration 3
# Variable dropped: Women age 15-49 currently pregnant (%) ; p-value of variable: 0.3265506589006544
# OLD AIC: -146.78395448431425
# Degrees of freedom: 7
# NEW AIC: -146.5843863550774
# ['Total Population', 'Proportion who suffered incidence of sickness in past 2 weeks', 'Of those who suffered sickness proportion who suffered fever or malaria', 'Proportion of children aged 6-23 months fed minimum dietary diversity', 'HIV prevalence among 15-49 (%)', 'Proportion chronically ill', 'Of those chronically ill proportion with mental illness']
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Total EHP Cost   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.695e+05
# Date:                Wed, 26 Feb 2020   Prob (F-statistic):           1.55e-50
# Time:                        15:19:10   Log-Likelihood:                 37.656
# No. Observations:                  29   AIC:                            -61.31
# Df Residuals:                      22   BIC:                            -51.74
# Df Model:                           7
# Covariance Type:            nonrobust
# ===========================================================================================================================================
#                                                                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------
# Total Population                                                            0.9992      0.016     61.680      0.000       0.966       1.033
# Proportion who suffered incidence of sickness in past 2 weeks               0.1619      0.043      3.737      0.001       0.072       0.252
# Of those who suffered sickness proportion who suffered fever or malaria     0.2906      0.083      3.502      0.002       0.118       0.463
# Proportion of children aged 6-23 months fed minimum dietary diversity      -0.0635      0.057     -1.121      0.275      -0.181       0.054
# HIV prevalence among 15-49 (%)                                              0.2924      0.032      9.262      0.000       0.227       0.358
# Proportion chronically ill                                                  0.1597      0.060      2.679      0.014       0.036       0.283
# Of those chronically ill proportion with mental illness                     0.0288      0.023      1.232      0.231      -0.020       0.077
# ==============================================================================
# Omnibus:                        6.562   Durbin-Watson:                   1.614
# Prob(Omnibus):                  0.038   Jarque-Bera (JB):                5.011
# Skew:                           0.983   Prob(JB):                       0.0816
# Kurtosis:                       3.532   Cond. No.                         99.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Iteration 1
# Variable dropped: Propotion of children <5 -3 SD below weight-for-age ; p-value of variable: 0.7373287933314085
# OLD AIC: -191.5649107854428
# Degrees of freedom: 9
# NEW AIC: -193.34055205526607
# Iteration 2
# Variable dropped: Proportion of children aged 6-23 months fed minimum dietary diversity ; p-value of variable: 0.5584115511212489
# OLD AIC: -193.34055205526607
# Degrees of freedom: 8
# NEW AIC: -195.07420774329503
# Iteration 3
# Variable dropped: Women age 15-49 currently pregnant (%) ; p-value of variable: 0.5192444921474927
# OLD AIC: -195.07420774329503
# Degrees of freedom: 7
# NEW AIC: -196.54517639306087
# Iteration 4
# Variable dropped: Of those chronically ill proportion with Epilepsy ; p-value of variable: 0.351803782672815
# OLD AIC: -196.54517639306087
# Degrees of freedom: 6
# NEW AIC: -197.3437205706953
# Iteration 5
# Variable dropped: Proportion who suffered incidence of sickness in past 2 weeks ; p-value of variable: 0.10942673762193444
# OLD AIC: -197.3437205706953
# Degrees of freedom: 5
# NEW AIC: -195.97698833433333
# ['Total Population', 'Of those who suffered sickness proportion who suffered fever or malaria', 'HIV prevalence among 15-49 (%)', 'Proportion chronically ill', 'Of those chronically ill proportion with mental illness']
#                                                     OLS Regression Results
# =============================================================================================================================
# Dep. Variable:     Total EHP Cost (less donor contributions) - using RM program data   R-squared:                       1.000
# Model:                                                                           OLS   Adj. R-squared:                  1.000
# Method:                                                                Least Squares   F-statistic:                 1.048e+06
# Date:                                                               Wed, 26 Feb 2020   Prob (F-statistic):           3.10e-63
# Time:                                                                       15:19:10   Log-Likelihood:                 61.676
# No. Observations:                                                                 29   AIC:                            -113.4
# Df Residuals:                                                                     24   BIC:                            -106.5
# Df Model:                                                                          5
# Covariance Type:                                                           nonrobust
# ===========================================================================================================================================
#                                                                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------
# Total Population                                                            0.9853      0.007    149.723      0.000       0.972       0.999
# Of those who suffered sickness proportion who suffered fever or malaria     0.0843      0.028      3.056      0.005       0.027       0.141
# HIV prevalence among 15-49 (%)                                              0.0309      0.013      2.413      0.024       0.004       0.057
# Proportion chronically ill                                                  0.1062      0.023      4.638      0.000       0.059       0.154
# Of those chronically ill proportion with mental illness                     0.0421      0.010      4.385      0.000       0.022       0.062
# ==============================================================================
# Omnibus:                        1.707   Durbin-Watson:                   2.437
# Prob(Omnibus):                  0.426   Jarque-Bera (JB):                1.043
# Skew:                           0.010   Prob(JB):                        0.594
# Kurtosis:                       2.071   Cond. No.                         74.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
